# %% [markdown]
# Requirements and Dependencies

# %%
# Install necessary libraries
# !pip install alpaca-py
# !pip install alpaca_trade_api
# !pip install tensorflow
# !pip install tensorflowjs
# !pip install scikit-learn

# %%
# Import libraries
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import random
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import requests
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from tabulate import tabulate
import tensorflowjs as tfjs
from alpaca_trade_api import REST
from alpaca.data.historical import CryptoHistoricalDataClient
from alpaca.data.requests import CryptoBarsRequest, StockLatestQuoteRequest
from alpaca.data.timeframe import TimeFrame
from alpaca.data.live import StockDataStream
from alpaca.trading.client import TradingClient
from alpaca.trading.requests import MarketOrderRequest
from alpaca.trading.enums import TimeInForce, AssetClass
from alpaca.data.historical import StockHistoricalDataClient
from alpaca.trading.requests import LimitOrderRequest, GetAssetsRequest, GetOrdersRequest
from alpaca.trading.requests import GetOrdersRequest
from alpaca.trading.enums import OrderSide, QueryOrderStatus
import math
from collections import defaultdict



ALPACA_API_KEY = "PKWZQPWFN48ANDCSHDJZ"
ALPACA_API_SECRET = "a88iGvrTfywVtrcQxO0vnsE9xwlSKtIjkRpcIf6C"
ALPACA_BASE_URL = "https://paper-api.alpaca.markets"

ALPACA_CREDS = {
    "API_KEY":ALPACA_API_KEY,
    "API_SECRET": ALPACA_API_SECRET,
    "PAPER": True
}

api = REST(base_url=ALPACA_BASE_URL, key_id=ALPACA_API_KEY, secret_key=ALPACA_API_SECRET)
trading_client = TradingClient(ALPACA_API_KEY, ALPACA_API_SECRET, paper=True)
client_hist = StockHistoricalDataClient(ALPACA_API_KEY, ALPACA_API_SECRET)


#FMP API for training data
api_key_fmp = "dc16ae239a0a90cc7f039177aa18aa33"

### TRAINING CODE

def fetch_stock_data(symbol, from_date, to_date):
    api_url = f"https://financialmodelingprep.com/api/v3/historical-price-full/{symbol}?apikey={api_key_fmp}&from={from_date}&to={to_date}"
    response = requests.get(api_url)
    data = response.json()
    if data:
        historical_data = data['historical']

        reversed_data = historical_data[::-1]
        return reversed_data
    else:
      print(f"Error in data fetching: {data}")
      return data

# Define function for data preprocessing
def preprocess_data(data):
    closing_prices = [day['close'] for day in data]
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(np.array(closing_prices).reshape(-1, 1))
    return scaled_data, scaler, [day['date'] for day in data], closing_prices

# Define function to create sequences for LSTM
def create_sequences(data, seq_length):
    X, y = [], []
    padded_data = np.pad(data, ((seq_length - 1, 0), (0, 0)), mode='constant', constant_values=0.5)

    # Iterate through the padded data to create sequences
    for i in range(len(data)):
        sequence = padded_data[i:(i + seq_length)]
        X.append(sequence)
        y.append(data[i])

    return np.array(X), np.array(y)

# Define function to build LSTM model
def build_lstm_model(seq_length):

    model = Sequential([layers.Input((seq_length, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dropout(0.2),
                    layers.Dense(1)])

    model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])
    return model

def build_redundant_lstm_models(seq_length, num_models):
    models = []
    for _ in range(num_models):
        model = build_lstm_model(seq_length)
        models.append(model)
    return models

# Define function for training the model
def train_model(model, X_train, y_train, X_val, y_val, epochs, batch_size):
    model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=epochs, batch_size=batch_size, verbose=0)
    return model

# Define function to save the trained model
def save_model(model, filename):
    model.save(filename + '.h5')  # Save the model in the native Keras format


# Define function to calculate model accuracy
def calculate_accuracy(model, X_test, y_test):
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    return rmse

def run_code(symbol, start_date, end_date, future_days):
    seq_length = 20
    epochs = 100
    batch_size = 32
    model_filename = 'stock_prediction_model'

    # Fetch data
    stock_data = fetch_stock_data(symbol, start_date, end_date)

    # Preprocess data
    scaled_data, scaler, dates, closing_prices = preprocess_data(stock_data)

    # Create sequences
    X, y = create_sequences(scaled_data, seq_length)

    # Split data into training, validation, and testing sets
    q_80 = int(len(X) * 0.8)
    q_90 = int(len(X) * 0.9)

    X_train, y_train = X[:q_80], y[:q_80]
    X_val, y_val = X[q_80:q_90], y[q_80:q_90]
    X_test, y_test = X[q_90:], y[q_90:]

    dates_train = [dates[i] for i in range(q_80)]
    dates_val = [dates[q_80 + i] for i in range(len(y_val))]
    dates_test = [dates[q_90 + i] for i in range(len(y_test))]

    dates_train = [datetime.strptime(date_str, '%Y-%m-%d').date() for date_str in dates_train]
    dates_val = [datetime.strptime(date_str, '%Y-%m-%d').date() for date_str in dates_val]
    dates_test = [datetime.strptime(date_str, '%Y-%m-%d').date() for date_str in dates_test]

    # Reshape data for LSTM
    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

    # Build LSTM model
    model = build_lstm_model(seq_length)

    # Train model
    model = train_model(model, X_train, y_train, X_val, y_val, epochs, batch_size)

    rmse = calculate_accuracy(model, X_test, y_test)

    print("accuracy", rmse)

    # Save model
    # save_model(model, model_filename)
    # tf.saved_model.save(model, './')
    tfjs.converters.save_keras_model(model, "./model_tfjs")

    # Predict using the trained model
    y_train_pred = model.predict(X_train)
    y_val_pred = model.predict(X_val)
    y_test_pred = model.predict(X_test)


    # Inverse transform the predicted and actual values
    y_train_actual = scaler.inverse_transform(y_train.reshape(-1, 1))
    y_train_pred_actual = scaler.inverse_transform(y_train_pred)

    y_val_actual = scaler.inverse_transform(y_val.reshape(-1, 1))
    y_val_pred_actual = scaler.inverse_transform(y_val_pred)

    y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))
    y_test_pred_actual = scaler.inverse_transform(y_test_pred)

    plt.figure(figsize=(10, 6))

    # Plot training data
    plt.plot(dates_train, y_train_actual,color='blue', label='Training Actual')
    plt.plot(dates_train, y_train_pred_actual, color='orange', label='Training Predicted')

    # Plot validation data
    plt.plot(dates_val, y_val_actual, color='blue', label='Validation Actual')
    plt.plot(dates_val, y_val_pred_actual, color='red', label='Validation Predicted')

    # Plot testing data
    plt.plot(dates_test, y_test_actual,color='blue', label='Testing Actual')
    plt.plot(dates_test, y_test_pred_actual, color='green', label='Testing Predicted')

    print(dates_test, y_test_pred_actual)

    # Extend predictions for additional days
    future_prices = []

    X_extend = X[-3:].copy()
    inverse_X = scaler.inverse_transform(X.reshape(-1, 1))

    for _ in range(future_days):  # Predict for the next 7 days
        future_price = model.predict(X_extend)[0][0]

        future_prices.append(future_price)
        X_extend = np.roll(X_extend, -1)
        X_extend[-1][-1] = future_price
        # print(X_extend)

    future_prices_actual = scaler.inverse_transform(np.array(future_prices).reshape(-1, 1))

    # # Extend predictions
    future_dates = generate_date_range(dates_test[-1] + timedelta(days=1), dates_test[-1] + timedelta(days=future_days))

    plt.plot(future_dates, future_prices_actual, color='purple', label='Future Predictions')

    plt.title(f'{symbol} Actual vs. Predicted Closing Prices')
    plt.xlabel('Date')
    plt.ylabel('Closing Price $')
    plt.xticks(rotation=45)
    plt.legend()
    plt.tight_layout()
    plt.show()

    return dates_test, closing_prices, future_prices_actual, rmse


def generate_date_range(start_date, end_date):
    return [start_date + timedelta(days=i) for i in range((end_date - start_date).days + 1)]

########## Stock API Functions ##############

def get_portfolio_symbols():
    # Get list of positions
    positions = api.list_positions()

    return positions

def execute_trade(symbol, quantity, side):
    market_order_data = MarketOrderRequest(
                            symbol=symbol,
                            qty=quantity,
                            side=side,
                            time_in_force=TimeInForce.DAY
                        )
    market_order = trading_client.submit_order(order_data=market_order_data)


def main():
    today_date = datetime.today()
    six_months_ago = today_date - timedelta(days=30*6)
    # Format today's date as 'YYYY-MM-DD'
    start_date = six_months_ago.strftime('%Y-%m-%d')
    end_date = today_date.strftime('%Y-%m-%d')
    future_days = 3
    #Get previous order prices
    portfolio = get_portfolio_symbols()
    assets = trading_client.get_all_positions()

    current_PL = {}
    # Iterate over each order and apppend data to dictionary
    for asset in assets:
        symbol = asset.symbol
        current_price = asset.current_price
        avg_entry_price = float(asset.avg_entry_price)
        qty = float(asset.qty)
        market_value = float(asset.market_value)
        pl_percentage = ((market_value - (avg_entry_price * qty)) / (avg_entry_price * qty)) * 100
        current_PL[symbol] = {'PL_percentage': pl_percentage, 'qty': qty, 'current_price': current_price}

    print(current_PL)

    for position in portfolio:
        symbol = position.symbol

        # relevant prices for the stock
        percentage = float(current_PL[symbol]['PL_percentage'])
        quantity = int(current_PL[symbol]['qty'])
        current_price = float(current_PL[symbol]['current_price'])

        # Prediction Code
        dates_test, closing_prices, future_prices_actual, accuracy = run_code(symbol, start_date, end_date, future_days)
        closing_prices = closing_prices[::-1]
        print(closing_prices)
        print(future_prices_actual)

        # determine trend based on todays price and tomorrows predicted price
        if future_prices_actual[0] > closing_prices[0]:
          print("future price is bigger",future_prices_actual[0], closing_prices[0])

        # get all cash available are trade with 20 %
        quantity_trade_with = math.floor(int(quantity)/5)
        profit_curr_trade = math.floor(int(current_price * 1.10))
        stop_loss_curr_trade = math.floor(int(current_price * 0.9))

        # Determine future trend is upwards buy and also check accuracy is above 90% and we are starting to make a profit
        if future_prices_actual[0] > closing_prices[0] and accuracy < 0.1:
            # Buy order with stop loss and take profit
            print("submit buy order based on predictions for ", symbol, quantity_trade_with)
            api.submit_order(
                symbol=symbol,
                side='buy',
                type='market',
                qty=quantity_trade_with,
                time_in_force='day',
                order_class='bracket',
                take_profit=dict(
                    limit_price=str(profit_curr_trade),  # Example: Take profit at 10% above average filled price
                ),
                stop_loss=dict(
                    stop_price=str(stop_loss_curr_trade),  # Example: Stop loss at 10% below average filled price
                    limit_price=str(stop_loss_curr_trade),  # Same as stop_price for market orders
                )
            )

        # Current qty and stock trades based on stop loss and profit
        if ( percentage <= -9.0 ):
          print("Cut our losses")
          execute_trade(symbol, quantity/2, 'sell')
        if ( percentage >= 6.0 ):
          print("Take our profits")
          execute_trade(symbol, quantity/2, 'sell')

if __name__ == "__main__":
    main()


print("cronjob")
# Out:
# {'AAPL': {'PL_percentage': -0.05911563017262361, 'qty': 9.0, 'current_price': '169.06'}, 'ARM': {'PL_percentage': 6.366413351214415, 'qty': 33.0, 'current_price': '142.765'}, 'META': {'PL_percentage': 6.2607150971846455, 'qty': 3.0, 'current_price': '514.44'}, 'NVDA': {'PL_percentage': 0.0026123301985281192, 'qty': 30.0, 'current_price': '918.744'}, 'SHOP': {'PL_percentage': -0.641326488131066, 'qty': 202.0, 'current_price': '74.4497'}, 'TSLA': {'PL_percentage': -7.183499288762453, 'qty': 10.0, 'current_price': '177.48'}}
# 1/1 [==============================] - 0s 471ms/step
# accuracy 0.0699706222449795
# 4/4 [==============================] - 0s 11ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# [datetime.date(2024, 2, 20), datetime.date(2024, 2, 21), datetime.date(2024, 2, 22), datetime.date(2024, 2, 23), datetime.date(2024, 2, 26), datetime.date(2024, 2, 27), datetime.date(2024, 2, 28), datetime.date(2024, 2, 29), datetime.date(2024, 3, 1), datetime.date(2024, 3, 4), datetime.date(2024, 3, 5), datetime.date(2024, 3, 6), datetime.date(2024, 3, 7)] [[183.1708 ]
#  [183.07965]
#  [184.25652]
#  [184.1453 ]
#  [183.44815]
#  [183.71335]
#  [183.341  ]
#  [182.78012]
#  [181.83192]
#  [178.83781]
#  [174.39392]
#  [171.26106]
#  [169.81532]]
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# [169.145, 169.12, 170.12, 175.1, 179.66, 180.75, 181.42, 182.63, 181.16, 182.52, 184.37, 182.32, 181.56, 182.31, 183.86, 184.15, 185.04, 187.15, 188.85, 188.32, 189.41, 189.3, 187.68, 185.85, 186.86, 184.4, 188.04, 191.73, 192.42, 194.17, 194.5, 195.18, 193.89, 191.56, 188.63, 182.68, 183.63, 185.92, 185.59, 186.19, 185.14, 185.56, 181.18, 181.91, 184.25, 185.64, 192.53, 193.58, 193.15, 193.05, 193.6, 194.68, 194.83, 196.94, 195.89, 197.57, 198.11, 197.96, 194.71, 193.18, 195.71, 194.27, 192.32, 193.42, 189.43, 191.24, 189.95, 189.37, 190.4, 189.79, 189.97, 191.31, 190.64, 191.45, 189.69, 189.71, 188.01, 187.44, 184.8, 186.4, 182.41, 182.89, 181.82, 179.23, 176.65, 177.57, 173.97, 170.77, 170.29, 168.22, 166.89, 171.1, 173.44, 173, 172.88, 175.46, 175.84, 177.15, 178.72, 178.85, 180.71, 179.8, 178.39, 178.99, 177.49, 174.91, 173.66, 172.4, 173.75, 171.21, 170.69, 170.43, 171.96, 176.08, 174.79, 173.93, 175.49, 179.07, 177.97, 175.01, 175.74, 174.21, 176.3, 179.36]
# [[174.39392]
#  [181.88194]
#  [185.36421]]
# future price is bigger [174.39392] 169.145
# submit buy order based on predictions for  AAPL 1
# 1/1 [==============================] - 0s 494ms/step
# accuracy 0.5674323430987398
# 3/3 [==============================] - 0s 10ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# [datetime.date(2024, 2, 21), datetime.date(2024, 2, 22), datetime.date(2024, 2, 23), datetime.date(2024, 2, 26), datetime.date(2024, 2, 27), datetime.date(2024, 2, 28), datetime.date(2024, 2, 29), datetime.date(2024, 3, 1), datetime.date(2024, 3, 4), datetime.date(2024, 3, 5), datetime.date(2024, 3, 6), datetime.date(2024, 3, 7)] [[95.61411 ]
#  [91.25298 ]
#  [88.65865 ]
#  [90.57078 ]
#  [86.77854 ]
#  [81.00898 ]
#  [78.64994 ]
#  [76.138   ]
#  [72.9809  ]
#  [69.74049 ]
#  [68.33264 ]
#  [68.767235]]
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# [143.38, 136.99, 134.07, 138.01, 141.62, 141.04, 133.86, 137.95, 146.2, 133.34, 128.53, 123.39, 121.77, 128.34, 133.68, 126.4, 119.98, 148.97, 115.21, 113.89, 77.01, 72.98, 73.27, 71, 70.52, 70.67, 71.97, 72.93, 71.17, 73.91, 75.74, 76.35, 77.11, 78.58, 74.23, 69.86, 68.48, 70, 69.77, 70.77, 71.88, 72.84, 67.05, 68.39, 67.91, 68.92, 75.15, 77.47, 74.25, 73.41, 72.29, 71.2, 68.4, 69.43, 68.87, 71.03, 70.74, 65.61, 64.71, 64.89, 67.23, 62.44, 61.06, 63.59, 61.93, 63.9, 61.5, 62.21, 61.92, 61, 63.88, 61.76, 58.66, 58.68, 54.99, 54.23, 55.43, 53.43, 51.69, 52.27, 51.58, 54.4, 55.27, 53.1, 53.49, 52.82, 50.52, 49.29, 47.9, 49.09, 50.17, 49.44, 52.37, 50.21, 47.87, 49.74, 51.9, 52.29, 52.09, 50.78, 51.85, 54.68, 55.71, 54.25, 54.08, 52.51, 53.46, 51.57, 52.26, 53.52, 55.49, 52.99, 53.52, 54.44, 51.32, 52.16, 52.91, 55.17, 58, 60.75]
# [[69.74049]
#  [58.04103]
#  [57.8032 ]]
# Take our profits
# 1/1 [==============================] - 0s 469ms/step
# accuracy 0.3301118935113898
# 4/4 [==============================] - 0s 8ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# [datetime.date(2024, 2, 20), datetime.date(2024, 2, 21), datetime.date(2024, 2, 22), datetime.date(2024, 2, 23), datetime.date(2024, 2, 26), datetime.date(2024, 2, 27), datetime.date(2024, 2, 28), datetime.date(2024, 2, 29), datetime.date(2024, 3, 1), datetime.date(2024, 3, 4), datetime.date(2024, 3, 5), datetime.date(2024, 3, 6), datetime.date(2024, 3, 7)] [[425.71423]
#  [413.86584]
#  [419.7218 ]
#  [419.50528]
#  [415.36826]
#  [415.17484]
#  [410.30478]
#  [410.13147]
#  [417.7435 ]
#  [417.7724 ]
#  [408.3792 ]
#  [405.42654]
#  [418.05093]]
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 37ms/step
# [515.426, 496.09, 490.22, 498.19, 502.3, 490.13, 484.02, 487.05, 481.74, 484.03, 486.13, 468.03, 471.75, 473.32, 484.03, 473.28, 460.12, 468.9, 468.11, 470, 469.59, 454.72, 459.41, 474.99, 394.78, 390.14, 400.06, 401.02, 394.14, 393.18, 390.7, 385.2, 381.78, 383.45, 376.13, 368.37, 367.46, 374.49, 369.67, 370.47, 357.43, 358.66, 351.95, 347.12, 344.47, 346.29, 353.96, 358.32, 357.83, 354.83, 353.39, 354.09, 349.28, 350.36, 344.62, 334.92, 333.17, 334.74, 334.22, 325.28, 332.75, 326.59, 317.45, 318.29, 320.02, 324.82, 327.15, 332.2, 338.99, 334.7, 338.23, 341.49, 336.98, 339.97, 335.04, 334.19, 332.71, 336.31, 329.19, 328.77, 320.55, 319.78, 318.82, 315.8, 314.6, 310.87, 311.85, 301.27, 302.66, 296.73, 288.35, 299.53, 312.55, 314.01, 308.65, 312.81, 316.97, 324, 321.15, 314.69, 324.16, 327.82, 321.84, 318.36, 315.43, 304.79, 305.58, 300.94, 306.82, 300.21, 303.96, 297.74, 298.96, 300.83, 299.08, 295.73, 299.67, 305.07, 302.55, 300.31, 311.72, 305.06, 301.66, 307.56]
# [[408.3792 ]
#  [383.54477]
#  [370.25647]]
# Take our profits
# 1/1 [==============================] - 1s 734ms/step
# accuracy 0.3511964804037833
# 4/4 [==============================] - 0s 7ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# [datetime.date(2024, 2, 20), datetime.date(2024, 2, 21), datetime.date(2024, 2, 22), datetime.date(2024, 2, 23), datetime.date(2024, 2, 26), datetime.date(2024, 2, 27), datetime.date(2024, 2, 28), datetime.date(2024, 2, 29), datetime.date(2024, 3, 1), datetime.date(2024, 3, 4), datetime.date(2024, 3, 5), datetime.date(2024, 3, 6), datetime.date(2024, 3, 7)] [[595.60516]
#  [551.34607]
#  [582.04956]
#  [605.86383]
#  [624.23895]
#  [631.9679 ]
#  [626.0741 ]
#  [623.481  ]
#  [632.9802 ]
#  [649.6034 ]
#  [656.5587 ]
#  [667.62866]
#  [681.3397 ]]
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 45ms/step
# [917.8779, 887, 859.64, 852.37, 822.79, 791.12, 776.63, 787.01, 790.92, 788.17, 785.38, 674.72, 694.52, 726.13, 726.58, 739, 721.28, 722.48, 721.33, 696.41, 700.99, 682.23, 693.32, 661.6, 630.27, 615.27, 627.74, 624.65, 610.31, 616.17, 613.62, 598.73, 596.54, 594.91, 571.07, 560.53, 563.82, 547.1, 548.22, 543.5, 531.4, 522.53, 490.97, 479.98, 475.69, 481.68, 495.22, 495.22, 494.17, 492.79, 488.3, 489.9, 481.11, 496.04, 500.77, 488.9, 483.5, 480.88, 476.57, 466.27, 475.06, 465.96, 455.03, 465.66, 455.1, 467.65, 467.7, 481.4, 478.21, 482.42, 477.76, 487.16, 499.44, 504.09, 492.98, 494.8, 488.88, 496.56, 486.2, 483.35, 469.5, 465.74, 459.55, 457.51, 450.05, 435.06, 423.25, 407.8, 411.61, 405, 403.26, 417.79, 436.63, 429.75, 413.87, 421.01, 421.96, 439.38, 460.95, 454.61, 469.45, 468.06, 457.98, 452.73, 457.62, 446.88, 440.41, 435.17, 447.82, 434.99, 430.89, 424.68, 419.11, 422.22, 416.1, 410.17, 422.39, 435.2, 439.66, 439, 455.81, 454.85, 448.7, 451.78]
# [[656.5587]
#  [567.0013]
#  [534.8083]]
# 1/1 [==============================] - 0s 461ms/step
# accuracy 0.037948510215851335
# 4/4 [==============================] - 0s 8ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# [datetime.date(2024, 2, 20), datetime.date(2024, 2, 21), datetime.date(2024, 2, 22), datetime.date(2024, 2, 23), datetime.date(2024, 2, 26), datetime.date(2024, 2, 27), datetime.date(2024, 2, 28), datetime.date(2024, 2, 29), datetime.date(2024, 3, 1), datetime.date(2024, 3, 4), datetime.date(2024, 3, 5), datetime.date(2024, 3, 6), datetime.date(2024, 3, 7)] [[79.43592 ]
#  [77.02397 ]
#  [75.10923 ]
#  [74.3934  ]
#  [74.6013  ]
#  [74.48606 ]
#  [74.0691  ]
#  [74.18736 ]
#  [74.44223 ]
#  [74.34778 ]
#  [73.383705]
#  [72.948006]
#  [72.870285]]
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# [74.46, 74.01, 73.47, 75.77, 76.59, 76.37, 75.56, 76.63, 77.56, 76.24, 75.03, 75.59, 78.62, 81.29, 84, 80.67, 77.18, 89.12, 90.72, 87.87, 85.17, 81.56, 81.4, 82.93, 76.72, 80.07, 82.33, 83.54, 81.55, 80.49, 80.73, 81.14, 80.26, 80.01, 77.52, 80.32, 81.32, 81.4, 81.3, 81.1, 80.11, 77.69, 74.51, 73.42, 71.82, 73.83, 77.9, 79.11, 78.34, 78.21, 76.83, 76.14, 75.42, 78.35, 77.13, 76.82, 77.54, 73.86, 72.5, 72.81, 72.52, 71.86, 71.14, 74.72, 72.52, 73.86, 72.82, 73.33, 73.51, 73.79, 70.35, 70.96, 69.73, 69.51, 68.34, 67.28, 67.85, 65.52, 62.34, 61.34, 60.37, 62.74, 61.69, 60.43, 61.47, 59.7, 48.79, 47.19, 46.92, 46.4, 46.69, 48.49, 52.35, 51, 51.14, 51.83, 52.84, 54.17, 53.28, 51.55, 53.33, 54.24, 55.08, 53.51, 53.65, 52.19, 52.58, 51.38, 54, 54.57, 53.2, 51.85, 51.51, 53.58, 53.08, 53.7, 56.97, 58.33, 59.5, 62.38, 63.4, 62.62, 62.93, 64.56]
# [[73.383705]
#  [76.94358 ]
#  [80.25683 ]]
# 1/1 [==============================] - 0s 489ms/step
# accuracy 0.09021109020005158
# 4/4 [==============================] - 0s 8ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# [datetime.date(2024, 2, 20), datetime.date(2024, 2, 21), datetime.date(2024, 2, 22), datetime.date(2024, 2, 23), datetime.date(2024, 2, 26), datetime.date(2024, 2, 27), datetime.date(2024, 2, 28), datetime.date(2024, 2, 29), datetime.date(2024, 3, 1), datetime.date(2024, 3, 4), datetime.date(2024, 3, 5), datetime.date(2024, 3, 6), datetime.date(2024, 3, 7)] [[201.30437]
#  [201.35625]
#  [202.01555]
#  [200.64185]
#  [201.84474]
#  [202.82727]
#  [204.2626 ]
#  [205.21579]
#  [206.04579]
#  [201.76042]
#  [196.09686]
#  [191.78296]
#  [190.10974]]
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# [177.7101, 176.54, 180.74, 188.14, 202.64, 201.88, 202.04, 199.73, 199.4, 191.97, 197.41, 194.77, 193.76, 199.95, 200.45, 188.71, 184.02, 188.13, 193.57, 189.56, 187.58, 185.1, 181.06, 187.91, 188.86, 187.29, 191.59, 190.93, 183.25, 182.63, 207.83, 209.14, 208.8, 212.19, 211.88, 215.55, 219.91, 218.89, 227.22, 233.94, 234.96, 240.45, 237.49, 237.93, 238.45, 248.42, 248.48, 253.18, 261.44, 256.61, 252.54, 254.5, 247.14, 257.22, 252.08, 253.5, 251.05, 239.29, 237.01, 239.74, 243.84, 242.64, 239.37, 238.72, 235.58, 238.83, 240.08, 244.14, 246.72, 236.08, 235.45, 234.21, 241.2, 235.6, 234.3, 233.59, 242.84, 237.41, 223.71, 214.65, 209.98, 222.11, 222.18, 219.27, 219.96, 218.51, 205.66, 200.84, 197.36, 207.3, 205.76, 212.42, 216.52, 212.08, 211.99, 220.11, 242.68, 254.85, 253.92, 251.12, 258.87, 262.99, 263.62, 259.67, 260.53, 260.05, 261.16, 246.53, 251.6, 250.22, 246.38, 240.5, 244.12, 246.99, 244.88, 255.7, 262.59, 266.5, 265.28, 274.39, 276.04, 271.3, 267.48, 273.58]
# [[196.09686]
#  [194.16075]
#  [193.46529]]
# future price is bigger [196.09686] 177.7101
# submit buy order based on predictions for  TSLA 2
# cronjob

# %% [markdown]
# Imports and Model
